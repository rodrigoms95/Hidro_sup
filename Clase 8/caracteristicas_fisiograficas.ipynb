# %%
# Cálculo de algunas características fisiográficas de cuencas.

import numpy as np
import pandas as pd

from scipy import optimize
from scipy import integrate

from matplotlib import pyplot as plt

import geopandas as gpd

# %%
# Dirección de los datos.
path = "../Material/Clases/Clase 8/"

# Nombres de las cuencas.
nombres_sub = ["RH12Ai_subc.shp", "RH19Be_subc.shp"]
nombres_c   = ["RH12Ai_curvas.shp", "RH19Be_curvas.shp"]
nombres_r   = ["Río San Fernando.shp", "Coords Río San Fernando.shp"]

# Lista con las cuencas.
# Creamos una lista vacía que llenaremos luego
Cuencas = [None, None]
Curvas  = [None, None]
Rios    = [None, None]

# %%
# Abrimos la primera subcuenca.
i = 0

Cuencas[i] = gpd.read_file(path + nombres_sub[i])

# A coordenadas UTM 14N (m) (EPSG:32614).
Cuencas[i] = Cuencas[i].to_crs(32614)

# Datos.
print(Cuencas[i].loc[0])

# Forma de la cuenca.
Cuencas[i].explore()
# Out:
# ID                                                        303.0
# CVE_SUBCUE                                               RH12Ai
# CVE_RH                                                     RH12
# RH                                             LERMA - SANTIAGO
# CVE_CUE                                                       A
# CUENCA                                        R. LERMA - TOLUCA
# CVE_SUBC                                                      i
# SUBCUENCA                                              R. Gavia
# AREA_KM2                                                 579.87
# PERIMETRO                                                119.92
# TIPO                                                    ABIERTA
# DRENAJE1                                                 RH12Ab
# DESCARGA1                                                     1
# DRENAJE2                                                      -
# DESCARGA2                                                     0
# DRENAJE3                                                      -
# DESCARGA3                                                     0
# DRENAJE4                                                      -
# DESCARGA4                                                     0
# TOT_DESC                                                      1
# geometry      POLYGON ((426212.5338591255 2139507.726116025,...
# Name: 0, dtype: object
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c4fd3eadad45de8df31edaa8a2ea20f2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c4fd3eadad45de8df31edaa8a2ea20f2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_c4fd3eadad45de8df31edaa8a2ea20f2 = L.map(
#                 &quot;map_c4fd3eadad45de8df31edaa8a2ea20f2&quot;,
#                 {
#                     center: [19.38657610012034, -99.85657811377963],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_c4fd3eadad45de8df31edaa8a2ea20f2);
#
#
#
#
#
#             var tile_layer_5a44618b51f59568fdc8b2fcf014cbcc = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c4fd3eadad45de8df31edaa8a2ea20f2);
#
#
#             map_c4fd3eadad45de8df31edaa8a2ea20f2.fitBounds(
#                 [[19.241406695120336, -100.01062647427963], [19.531745505120345, -99.70252975327963]],
#                 {}
#             );
#
#
#         function geo_json_178a89e833e0a68cf995caec66195067_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_178a89e833e0a68cf995caec66195067_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_178a89e833e0a68cf995caec66195067_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_178a89e833e0a68cf995caec66195067_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_178a89e833e0a68cf995caec66195067_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_178a89e833e0a68cf995caec66195067.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_178a89e833e0a68cf995caec66195067_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_178a89e833e0a68cf995caec66195067 = L.geoJson(null, {
#                 onEachFeature: geo_json_178a89e833e0a68cf995caec66195067_onEachFeature,
#
#                 style: geo_json_178a89e833e0a68cf995caec66195067_styler,
#                 pointToLayer: geo_json_178a89e833e0a68cf995caec66195067_pointToLayer
#         });
#
#         function geo_json_178a89e833e0a68cf995caec66195067_add (data) {
#             geo_json_178a89e833e0a68cf995caec66195067
#                 .addData(data)
#                 .addTo(map_c4fd3eadad45de8df31edaa8a2ea20f2);
#         }
#             geo_json_178a89e833e0a68cf995caec66195067_add({&quot;bbox&quot;: [-100.01062647427963, 19.241406695120336, -99.70252975327963, 19.531745505120345], &quot;features&quot;: [{&quot;bbox&quot;: [-100.01062647427963, 19.241406695120336, -99.70252975327963, 19.531745505120345], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-99.70252975327963, 19.3482190231203], [-99.70268085627963, 19.34794833812028], [-99.70287028727965, 19.34764840712034], [-99.70305182427967, 19.34730901112032], [-99.70341045627967, 19.3467226511203], [-99.7037542942797, 19.34601457112033], [-99.70409803427964, 19.345271097120282], [-99.70453095427966, 19.344159088120286], [-99.70521835127968, 19.342711981120285], [-99.70664563227966, 19.34094702412026], [-99.70746117627964, 19.34023342412028], [-99.70844662427963, 19.339587785120333], [-99.

# %%
# Abrimos la segunda subcuenca.
i = 1

Cuencas[i] = gpd.read_file(path + nombres_sub[i])

# A coordenadas UTM 14N (m) (EPSG:32614).
Cuencas[i] = Cuencas[i].to_crs(32614)

# Datos.
print(Cuencas[i].loc[0])

# Forma de la cuenca.
Cuencas[i].explore()
# Out:
# ID                                                        155.0
# CVE_SUBCUE                                               RH19Be
# CVE_RH                                                     RH19
# RH                                                 COSTA GRANDE
# CVE_CUE                                                       B
# CUENCA                                    R. COYUQUILLA Y OTROS
# CVE_SUBC                                                      e
# SUBCUENCA                                           R. Petatlán
# AREA_KM2                                                 548.64
# PERIMETRO                                                142.88
# TIPO                                                    ABIERTA
# DRENAJE1                                                 RH19Bf
# DESCARGA1                                                     1
# DRENAJE2                                                      -
# DESCARGA2                                                     0
# DRENAJE3                                                      -
# DESCARGA3                                                     0
# DRENAJE4                                                      -
# DESCARGA4                                                     0
# TOT_DESC                                                      1
# geometry      POLYGON ((292114.7400555336 1964589.739102419,...
# Name: 0, dtype: object
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_32826b6d6121b1b7d10adc8809bcfa8d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_32826b6d6121b1b7d10adc8809bcfa8d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_32826b6d6121b1b7d10adc8809bcfa8d = L.map(
#                 &quot;map_32826b6d6121b1b7d10adc8809bcfa8d&quot;,
#                 {
#                     center: [17.64559105212029, -101.14330500077963],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_32826b6d6121b1b7d10adc8809bcfa8d);
#
#
#
#
#
#             var tile_layer_993cb78ed6801d72cd1bdc2858a60ba3 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_32826b6d6121b1b7d10adc8809bcfa8d);
#
#
#             map_32826b6d6121b1b7d10adc8809bcfa8d.fitBounds(
#                 [[17.499713548120276, -101.32715465627963], [17.791468556120307, -100.95945534527964]],
#                 {}
#             );
#
#
#         function geo_json_1f61e12ad0935671b8d8c5421d11cb20_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_1f61e12ad0935671b8d8c5421d11cb20_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_1f61e12ad0935671b8d8c5421d11cb20_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_1f61e12ad0935671b8d8c5421d11cb20_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_1f61e12ad0935671b8d8c5421d11cb20_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_1f61e12ad0935671b8d8c5421d11cb20.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_1f61e12ad0935671b8d8c5421d11cb20_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_1f61e12ad0935671b8d8c5421d11cb20 = L.geoJson(null, {
#                 onEachFeature: geo_json_1f61e12ad0935671b8d8c5421d11cb20_onEachFeature,
#
#                 style: geo_json_1f61e12ad0935671b8d8c5421d11cb20_styler,
#                 pointToLayer: geo_json_1f61e12ad0935671b8d8c5421d11cb20_pointToLayer
#         });
#
#         function geo_json_1f61e12ad0935671b8d8c5421d11cb20_add (data) {
#             geo_json_1f61e12ad0935671b8d8c5421d11cb20
#                 .addData(data)
#                 .addTo(map_32826b6d6121b1b7d10adc8809bcfa8d);
#         }
#             geo_json_1f61e12ad0935671b8d8c5421d11cb20_add({&quot;bbox&quot;: [-101.32715465627963, 17.499713548120276, -100.95945534527964, 17.791468556120307], &quot;features&quot;: [{&quot;bbox&quot;: [-101.32715465627963, 17.499713548120276, -100.95945534527964, 17.791468556120307], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-100.96076460827969, 17.758836510120293], [-100.96114549427966, 17.758727083120302], [-100.96150735627968, 17.758529704120313], [-100.9616718392797, 17.758167841120304], [-100.9616718392797, 17.75774018512027], [-100.96160604627967, 17.7572467361203], [-100.96140866727968, 17.756786184120287], [-100.96130997727968, 17.756424321120278], [-100.96130997727968, 17.75593087312031], [-100.96137577027963, 17.755371630120315], [-100.96144156327966, 17.754845285120286], [-100.96147446027963, 17.75

# %%
# Coeficiente de compacidad de Gravelius.

# El primer corchete escoge el primer elemento
# de la lista Cuencas, que es el geoDataFrame
# de la subcuenca R. Gavia. El segundo corchete 
# crea la columna Gravelius dentro del GeoDataFrame.
# Si una operación está dentro de un paréntesis, la
# podemos escribir a lo largo de varias filas.
# Dentro de dobles comillas, hay que poner comillas sencillas.
for i in range( len(Cuencas) ):
    Cuencas[i]["GRAVELIUS"] = ( Cuencas[i]["PERIMETRO"] /
        ( 2 * np.sqrt( np.pi * Cuencas[i]["AREA_KM2"] ) ) )
    
    print( "Gravelius subcuenca "
        + f"{Cuencas[i].loc[0, 'SUBCUENCA']}: "
        + f"{Cuencas[i].loc[0, 'GRAVELIUS']}" )
# Out:
# Gravelius subcuenca R. Gavia: 1.4048222187279467
# Gravelius subcuenca R. Petatlán: 1.7207698007667973

# %%
# Curvas de nivel.

# Cargamos los valores.
for i in range( len( Curvas ) ):
    Curvas[i] = gpd.read_file(path + nombres_c[i])
    # A coordenadas UTM 14N (m) (EPSG:32614).
    Curvas[i] = Curvas[i].to_crs(32614)
    # Las curvas son un recorte de unas más largas.
    # La longitud no es real y hay que recalcularla.
    Curvas[i]["LENGTH"] = Curvas[i].length / 1000

# Ordenamos por cota para verificar Δz.
# El argumento de head es la cantidad de filas a imprimir.
print( Curvas[i].sort_values("CONTOUR").head(10) )

# Incializamos gráfica.
fig, ax = plt.subplots()
fig.set_facecolor("w")
fig.set_dpi(150) 

Cuencas[i].plot(ax = ax, color = "None", edgecolor = "k")
Curvas[i].plot("CONTOUR", ax = ax, linewidth = 0.5)

fig.tight_layout()
plt.show()
# Out:
#        LENGTH   COV_  COV_ID  CONTOUR  \
# 70   1.652969  80774   44598      201
# 68  16.434123  80772   44598      201
# 67  10.770701  80771   44598      201
# 69  17.849448  80773   44598      201
# 60   6.583120  78308   44368      401
# 23   0.518248  52669   40091      401
# 62  16.298459  78310   44368      401
# 61  16.973425  78309   44368      401
# 64  16.582812  78312   44368      401
# 65  16.405409  78313   44368      401
#
#                                              geometry
# 70  LINESTRING (263788.726 1940519.020, 264147.233...
# 68  LINESTRING (260134.762 1946798.667, 259968.703...
# 67  LINESTRING (255671.531 1951058.875, 255937.259...
# 69  LINESTRING (268919.978 1946682.515, 269334.421...
# 60  LINESTRING (257092.517 1951138.962, 257222.981...
# 23  LINESTRING (272432.371 1946065.153, 272328.854...
# 62  LINESTRING (268224.169 1948843.659, 268233.608...
# 61  LINESTRING (261122.248 1948792.180, 261186.287...
# 64  LINESTRING (278480.666 1953632.296, 278464.372...
# 65  LINESTRING (270489.096 1948924.405, 270340.073...

# %%
# Pendiente de la cuenca de Alvard.

# Desnivel entre curvas [km]
D = 0.2

for i in range( len( Cuencas ) ):
    Cuencas[i]["ALVARD"] = ( D * Curvas[i]["LENGTH"].sum()
        / Cuencas[i]["AREA_KM2"] )
    
    # Pendiente en m/km.
    print( "Alvard subcuenca "
        + f"{Cuencas[i].loc[0, 'SUBCUENCA']}: "
        + f"{Cuencas[i].loc[0, 'ALVARD'] * 1000:.3f}" )
# Out:
# Alvard subcuenca R. Gavia: 69.81851468957277
# Alvard subcuenca R. Petatlán: 243.8020749149698

# %%
# Cargamos la información del Río San Fernando.

for i in range( len(Rios) ):
    Rios[i] = gpd.read_file(path + nombres_r[i])
    # Mexico ITRF92 UTM 14N (EPSG:32614).
    Rios[i] = Rios[i].to_crs(32614)

# Nube de puntos con información de cotas.
print( Rios[1].head() )
# Out:
#    FNODE_  TNODE_  LPOLY_  RPOLY_   LENGTH  COV_  COV_ID     NOMBRES  \
# 0    2605    2608       0       0  0.93024  1788    1967  R. Conchos
# 1    2605    2608       0       0  0.93024  1788    1967  R. Conchos
# 2    2605    2608       0       0  0.93024  1788    1967  R. Conchos
# 3    2605    2608       0       0  0.93024  1788    1967  R. Conchos
# 4    2605    2608       0       0  0.93024  1788    1967  R. Conchos
#
#    distance       angle     xcoord     ycoord  zcoord    Distancia  \
# 0      0.93  246.784079 -99.328513  24.944138   233.0     0.000000
# 1      0.92  267.382556 -99.319082  24.947030   225.0  1004.528814
# 2      0.91  267.382556 -99.309093  24.947487   222.0  1009.753687
# 3      0.90  267.382556 -99.299103  24.947943   219.0  1009.749188
# 4      0.89  267.382556 -99.289114  24.948400   225.0  1009.744714
#
#              x                        geometry
# 0     0.000000  POINT (466834.720 2758802.322)
# 1  1004.528814  POINT (467787.592 2759120.305)
# 2  2014.282501  POINT (468796.193 2759168.540)
# 3  3024.031689  POINT (469804.786 2759216.849)
# 4  4033.776403  POINT (470813.370 2759265.232)

# %%
# Vector del río.
Rios[0].explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_065e97210d6b8762aa9c803cb53f69ea {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_065e97210d6b8762aa9c803cb53f69ea&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_065e97210d6b8762aa9c803cb53f69ea = L.map(
#                 &quot;map_065e97210d6b8762aa9c803cb53f69ea&quot;,
#                 {
#                     center: [24.92031882670478, -98.7873776792039],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_065e97210d6b8762aa9c803cb53f69ea);
#
#
#
#
#
#             var tile_layer_044c467504464a2e3ddea5bf3379ba8a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_065e97210d6b8762aa9c803cb53f69ea);
#
#
#             map_065e97210d6b8762aa9c803cb53f69ea.fitBounds(
#                 [[24.724722926156595, -99.8795391437306], [25.115914727252964, -97.69521621467722]],
#                 {}
#             );
#
#
#         function geo_json_48f4c98811446185299db4ae8a978c3d_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_48f4c98811446185299db4ae8a978c3d_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_48f4c98811446185299db4ae8a978c3d_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_48f4c98811446185299db4ae8a978c3d_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_48f4c98811446185299db4ae8a978c3d_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_48f4c98811446185299db4ae8a978c3d.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_48f4c98811446185299db4ae8a978c3d_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_48f4c98811446185299db4ae8a978c3d = L.geoJson(null, {
#                 onEachFeature: geo_json_48f4c98811446185299db4ae8a978c3d_onEachFeature,
#
#                 style: geo_json_48f4c98811446185299db4ae8a978c3d_styler,
#                 pointToLayer: geo_json_48f4c98811446185299db4ae8a978c3d_pointToLayer
#         });
#
#         function geo_json_48f4c98811446185299db4ae8a978c3d_add (data) {
#             geo_json_48f4c98811446185299db4ae8a978c3d
#                 .addData(data)
#                 .addTo(map_065e97210d6b8762aa9c803cb53f69ea);
#         }
#             geo_json_48f4c98811446185299db4ae8a978c3d_add({&quot;bbox&quot;: [-99.8795391437306, 24.724722926156595, -97.69521621467722, 25.115914727252964], &quot;features&quot;: [{&quot;bbox&quot;: [-99.8795391437306, 24.79300197344394, -99.32988282825337, 24.94355035552056], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-99.32988282825337, 24.94355035552056], [-99.37553839165011, 24.923967337331714], [-99.41073649505928, 24.897891298446506], [-99.44855693910493, 24.889411533455117], [-99.49121837500802, 24.891178869829723], [-99.52924490977087, 24.873443343045725], [-99.57817926989082, 24.86698736458296], [-99.6237799638668, 24.87340090625869], [-99.661569572139, 24.86487003123269], [-99.70410157427169, 24.872123269665213], [-99.74219754065118, 24.849717641240307], [-99.76822177324925, 24.8206109066334], [-99.79881480

# %%
# Desplazamos las coordenadas un lugar.
gs = Rios[1]["geometry"].shift(1)
# Calculamos la distancia entre dos puntos adyacentes.
Rios[1]["Distancia"] = Rios[1]["geometry"].distance(gs)
# La posición del primer punto es 0, para los demás es una suma acumulada.
Rios[1].loc[0, "Distancia"] = 0
Rios[1]["x"] = Rios[1]["Distancia"].cumsum()

# Guardamos la distancia y la cota en otras variables.
x = Rios[1]["x"]
z = Rios[1]["zcoord"]

# Escogemos los valores iniciales y finales.
x_i = x.to_numpy()[0]
x_f = x.to_numpy()[-1]
z_f = z.to_numpy()[-1]
z_i = z.to_numpy()[0]

Rios[1]
# Out:
#      FNODE_  TNODE_  LPOLY_  RPOLY_   LENGTH  COV_  COV_ID          NOMBRES  \
# 0      2605    2608       0       0  0.93024  1788    1967       R. Conchos
# 1      2605    2608       0       0  0.93024  1788    1967       R. Conchos
# 2      2605    2608       0       0  0.93024  1788    1967       R. Conchos
# 3      2605    2608       0       0  0.93024  1788    1967       R. Conchos
# 4      2605    2608       0       0  0.93024  1788    1967       R. Conchos
# ..      ...     ...     ...     ...      ...   ...     ...              ...
# 205    2600    2601       0       0  1.15536  1794    1962  R. San Fernando
# 206    2600    2601       0       0  1.15536  1794    1962  R. San Fernando
# 207    2600    2601       0       0  1.15536  1794    1962  R. San Fernando
# 208    2600    2601       0       0  1.15536  1794    1962  R. San Fernando
# 209    2600    2601       0       0  1.15536  1794    1962  R. San Fernando
#
#      distance       angle     xcoord     ycoord  zcoord    Distancia  \
# 0        0.93  246.784079 -99.328513  24.944138   233.0     0.000000
# 1        0.92  267.382556 -99.319082  24.947030   225.0  1004.528814
# 2        0.91  267.382556 -99.309093  24.947487   222.0  1009.753687
# 3        0.90  267.382556 -99.299103  24.947943   219.0  1009.749188
# 4        0.89  267.382556 -99.289114  24.948400   225.0  1009.744714
# ..        ...         ...        ...        ...     ...          ...
# 205      0.04  252.988083 -97.727834  24.940236    -8.0  1018.530522
# 206      0.03  254.948968 -97.718223  24.942993     8.0  1017.389383
# 207      0.02  254.948968 -97.708566  24.945590    10.0  1016.648970
# 208      0.01  209.974830 -97.700212  24.949882     9.0   968.269174
# 209      0.00  209.974830 -97.695216  24.958545    10.0  1083.922582
#
#                  x                        geometry
# 0         0.000000  POINT (466834.720 2758802.322)
# 1      1004.528814  POINT (467787.592 2759120.305)
# 2      2014.282501  POINT (468796.193 2759168.540)
# 3      3024.031689  POINT (469804.786 2759216.849)
# 4      4033.776403  POINT (470813.370 2759265.232)
# ..             ...                             ...
# 205  211847.408318  POINT (628442.764 2758931.559)
# 206  212864.797701  POINT (629410.356 2759245.959)
# 207  213881.446670  POINT (630382.710 2759542.779)
# 208  214849.715845  POINT (631221.644 2760026.240)
# 209  215933.638427  POINT (631716.879 2760990.414)
#
# [210 rows x 16 columns]

# %%
# Recta de compensación.
def rect_comps(z_r):
    z = (z_f - z_r ) / (x_f - x_i) * (x - x_f) + z_f
    return z

# Integral de áreas compensadas.
def area_comps(z_r):
    a = rect_comps(z_r)
    I = integrate.simpson(z - a)
    return I

# %%
# Incializamos gráfica.
fig, ax = plt.subplots()
fig.set_facecolor("w")
fig.set_size_inches(6, 6)
fig.set_dpi(150) 

# Graficamos el perfil del río.
#ax.plot(x, z)

# Encontramos la cota z_r que compensa las áreas.
# Primer intento: z_i
z_r = optimize.fsolve(area_comps, x0 = z_i)

# Graficamos la recta compensada.
z_2 = rect_comps(z_r)
#ax.plot(x, z_2)

# Dibujamos las áreas compensadas.
ax.fill_between( x, z, z_2, where = z < z_2 )
ax.fill_between( x, z, z_2, where = z > z_2 )

# Pendiente.
S = (z_r - z_f ) / (x_f - x_i)
print(f"Pendiente [m/km]: {S * 1000}")

fig.tight_layout()
plt.show()
# Out:
# Pendiente [m/km]: [0.66735957]

# %%
# Tarea clase 8.
# 1. calcular la pendiente para el río Sonora por
# desnivel medio y por áreas compensadas y comparar.
# Utilizar UTM 12N (m) EPSG:32612 (https://epsg.io/32612)
# 2. Para las dos subcuencas calcula la densidad
# de corrientes, la densidad de drenaje, y el orden de la cuenca.
# Para el orden, utiliza la columna "ORDER".
