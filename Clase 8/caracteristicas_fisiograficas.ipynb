# %%
# Cálculo de algunas características fisiográficas de cuencas.

import numpy as np
import pandas as pd

from scipy import optimize
from scipy import integrate

from matplotlib import pyplot as plt

import geopandas as gpd

# %%
# Dirección de los datos.
path = "../Material/Clases/Clase 8/"

# Nombres de las cuencas.
nombres_sub = ["RH12Ai_subc.shp", "RH19Be_subc.shp"]
nombres_c   = ["RH12Ai_curvas.shp", "RH19Be_curvas.shp"]
nombres_r   = ["Río San Fernando.shp", "Coords Río San Fernando.shp"]
#nombres_r   = ["Río Sonora.shp", "Coords Río Sonora.shp"]

# Lista con las cuencas.
# Creamos una lista vacía que llenaremos luego
Cuencas = [None, None]
Curvas  = [None, None]
Rios    = [None, None]

# %%
# Abrimos la primera subcuenca.
i = 0

Cuencas[i] = gpd.read_file(path + nombres_sub[i])

# A coordenadas UTM 14N (m) (EPSG:32614).
Cuencas[i] = Cuencas[i].to_crs(32614)

# Datos.
print(Cuencas[i].loc[0])

# Forma de la cuenca.
Cuencas[i].explore()
# Out:
# ID                                                        303.0
# CVE_SUBCUE                                               RH12Ai
# CVE_RH                                                     RH12
# RH                                             LERMA - SANTIAGO
# CVE_CUE                                                       A
# CUENCA                                        R. LERMA - TOLUCA
# CVE_SUBC                                                      i
# SUBCUENCA                                              R. Gavia
# AREA_KM2                                                 579.87
# PERIMETRO                                                119.92
# TIPO                                                    ABIERTA
# DRENAJE1                                                 RH12Ab
# DESCARGA1                                                     1
# DRENAJE2                                                      -
# DESCARGA2                                                     0
# DRENAJE3                                                      -
# DESCARGA3                                                     0
# DRENAJE4                                                      -
# DESCARGA4                                                     0
# TOT_DESC                                                      1
# geometry      POLYGON ((426212.5338591255 2139507.726116025,...
# Name: 0, dtype: object
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5fb4d95269edcff00f36449e1d23f68e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5fb4d95269edcff00f36449e1d23f68e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_5fb4d95269edcff00f36449e1d23f68e = L.map(
#                 &quot;map_5fb4d95269edcff00f36449e1d23f68e&quot;,
#                 {
#                     center: [19.38657610012034, -99.85657811377963],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_5fb4d95269edcff00f36449e1d23f68e);
#
#
#
#
#
#             var tile_layer_a6637da302e762256ceae418172e062b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5fb4d95269edcff00f36449e1d23f68e);
#
#
#             map_5fb4d95269edcff00f36449e1d23f68e.fitBounds(
#                 [[19.241406695120336, -100.01062647427963], [19.531745505120345, -99.70252975327963]],
#                 {}
#             );
#
#
#         function geo_json_d8ba8c3daf1afef2dbabed239c7f4f9a_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_d8ba8c3daf1afef2dbabed239c7f4f9a_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_d8ba8c3daf1afef2dbabed239c7f4f9a_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_d8ba8c3daf1afef2dbabed239c7f4f9a_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_d8ba8c3daf1afef2dbabed239c7f4f9a_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_d8ba8c3daf1afef2dbabed239c7f4f9a.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_d8ba8c3daf1afef2dbabed239c7f4f9a_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_d8ba8c3daf1afef2dbabed239c7f4f9a = L.geoJson(null, {
#                 onEachFeature: geo_json_d8ba8c3daf1afef2dbabed239c7f4f9a_onEachFeature,
#
#                 style: geo_json_d8ba8c3daf1afef2dbabed239c7f4f9a_styler,
#                 pointToLayer: geo_json_d8ba8c3daf1afef2dbabed239c7f4f9a_pointToLayer
#         });
#
#         function geo_json_d8ba8c3daf1afef2dbabed239c7f4f9a_add (data) {
#             geo_json_d8ba8c3daf1afef2dbabed239c7f4f9a
#                 .addData(data)
#                 .addTo(map_5fb4d95269edcff00f36449e1d23f68e);
#         }
#             geo_json_d8ba8c3daf1afef2dbabed239c7f4f9a_add({&quot;bbox&quot;: [-100.01062647427963, 19.241406695120336, -99.70252975327963, 19.531745505120345], &quot;features&quot;: [{&quot;bbox&quot;: [-100.01062647427963, 19.241406695120336, -99.70252975327963, 19.531745505120345], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-99.70252975327963, 19.3482190231203], [-99.70268085627963, 19.34794833812028], [-99.70287028727965, 19.34764840712034], [-99.70305182427967, 19.34730901112032], [-99.70341045627967, 19.3467226511203], [-99.7037542942797, 19.34601457112033], [-99.70409803427964, 19.345271097120282], [-99.70453095427966, 19.344159088120286], [-99.70521835127968, 19.342711981120285], [-99.70664563227966, 19.34094702412026], [-99.70746117627964, 19.34023342412028], [-99.70844662427963, 19.339587785120333], [-99.

# %%
# Abrimos la segunda subcuenca.
i = 1

Cuencas[i] = gpd.read_file(path + nombres_sub[i])

# A coordenadas UTM 14N (m) (EPSG:32614).
Cuencas[i] = Cuencas[i].to_crs(32614)

# Datos.
print(Cuencas[i].loc[0])

# Forma de la cuenca.
Cuencas[i].explore()
# Out:
# ID                                                        155.0
# CVE_SUBCUE                                               RH19Be
# CVE_RH                                                     RH19
# RH                                                 COSTA GRANDE
# CVE_CUE                                                       B
# CUENCA                                    R. COYUQUILLA Y OTROS
# CVE_SUBC                                                      e
# SUBCUENCA                                           R. Petatlán
# AREA_KM2                                                 548.64
# PERIMETRO                                                142.88
# TIPO                                                    ABIERTA
# DRENAJE1                                                 RH19Bf
# DESCARGA1                                                     1
# DRENAJE2                                                      -
# DESCARGA2                                                     0
# DRENAJE3                                                      -
# DESCARGA3                                                     0
# DRENAJE4                                                      -
# DESCARGA4                                                     0
# TOT_DESC                                                      1
# geometry      POLYGON ((292114.7400555336 1964589.739102419,...
# Name: 0, dtype: object
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d9730389445f59b6801ac6ffec68776a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d9730389445f59b6801ac6ffec68776a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_d9730389445f59b6801ac6ffec68776a = L.map(
#                 &quot;map_d9730389445f59b6801ac6ffec68776a&quot;,
#                 {
#                     center: [17.64559105212029, -101.14330500077963],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_d9730389445f59b6801ac6ffec68776a);
#
#
#
#
#
#             var tile_layer_7bcbd945f4664b93bc5a2f09d459696c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d9730389445f59b6801ac6ffec68776a);
#
#
#             map_d9730389445f59b6801ac6ffec68776a.fitBounds(
#                 [[17.499713548120276, -101.32715465627963], [17.791468556120307, -100.95945534527964]],
#                 {}
#             );
#
#
#         function geo_json_a9dd0b0e10db1a7b3a90acd6f916a8c4_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_a9dd0b0e10db1a7b3a90acd6f916a8c4_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_a9dd0b0e10db1a7b3a90acd6f916a8c4_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_a9dd0b0e10db1a7b3a90acd6f916a8c4_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_a9dd0b0e10db1a7b3a90acd6f916a8c4_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_a9dd0b0e10db1a7b3a90acd6f916a8c4.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_a9dd0b0e10db1a7b3a90acd6f916a8c4_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_a9dd0b0e10db1a7b3a90acd6f916a8c4 = L.geoJson(null, {
#                 onEachFeature: geo_json_a9dd0b0e10db1a7b3a90acd6f916a8c4_onEachFeature,
#
#                 style: geo_json_a9dd0b0e10db1a7b3a90acd6f916a8c4_styler,
#                 pointToLayer: geo_json_a9dd0b0e10db1a7b3a90acd6f916a8c4_pointToLayer
#         });
#
#         function geo_json_a9dd0b0e10db1a7b3a90acd6f916a8c4_add (data) {
#             geo_json_a9dd0b0e10db1a7b3a90acd6f916a8c4
#                 .addData(data)
#                 .addTo(map_d9730389445f59b6801ac6ffec68776a);
#         }
#             geo_json_a9dd0b0e10db1a7b3a90acd6f916a8c4_add({&quot;bbox&quot;: [-101.32715465627963, 17.499713548120276, -100.95945534527964, 17.791468556120307], &quot;features&quot;: [{&quot;bbox&quot;: [-101.32715465627963, 17.499713548120276, -100.95945534527964, 17.791468556120307], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-100.96076460827969, 17.758836510120293], [-100.96114549427966, 17.758727083120302], [-100.96150735627968, 17.758529704120313], [-100.9616718392797, 17.758167841120304], [-100.9616718392797, 17.75774018512027], [-100.96160604627967, 17.7572467361203], [-100.96140866727968, 17.756786184120287], [-100.96130997727968, 17.756424321120278], [-100.96130997727968, 17.75593087312031], [-100.96137577027963, 17.755371630120315], [-100.96144156327966, 17.754845285120286], [-100.96147446027963, 17.75

# %%
# Coeficiente de compacidad de Gravelius.

# El primer corchete escoge el primer elemento
# de la lista Cuencas, que es el geoDataFrame
# de la subcuenca R. Gavia. El segundo corchete 
# crea la columna Gravelius dentro del GeoDataFrame.
# Si una operación está dentro de un paréntesis, la
# podemos escribir a lo largo de varias filas.
# Dentro de dobles comillas, hay que poner comillas sencillas.
for i in range( len(Cuencas) ):
    Cuencas[i]["GRAVELIUS"] = ( Cuencas[i]["PERIMETRO"] /
        ( 2 * np.sqrt( np.pi * Cuencas[i]["AREA_KM2"] ) ) )
    
    print( "Gravelius subcuenca "
        + f"{Cuencas[i].loc[0, 'SUBCUENCA']}: "
        + f"{Cuencas[i].loc[0, 'GRAVELIUS']:.3f}" )
# Out:
# Gravelius subcuenca R. Gavia: 1.405
# Gravelius subcuenca R. Petatlán: 1.721

# %%
# Curvas de nivel.

# Cargamos los valores.
for i in range( len( Curvas ) ):
    Curvas[i] = gpd.read_file(path + nombres_c[i])
    # A coordenadas UTM 14N (m) (EPSG:32614).
    Curvas[i] = Curvas[i].to_crs(32614)
    # Las curvas son un recorte de unas más largas.
    # La longitud no es real y hay que recalcularla.
    Curvas[i]["LENGTH"] = Curvas[i].length / 1000

# Ordenamos por cota para verificar Δz.
# El argumento de head es la cantidad de filas a imprimir.
print( Curvas[i].sort_values("CONTOUR").head(10) )

# Incializamos gráfica.
fig, ax = plt.subplots()
fig.set_facecolor("w")
fig.set_size_inches(6, 6)
fig.set_dpi(150) 

Cuencas[i].plot(ax = ax, color = "None", edgecolor = "k")
Curvas[i].plot("CONTOUR", ax = ax, linewidth = 0.5)

fig.tight_layout()
plt.show()
# Out:
#        LENGTH   COV_  COV_ID  CONTOUR  \
# 70   1.652969  80774   44598      201
# 68  16.434123  80772   44598      201
# 67  10.770701  80771   44598      201
# 69  17.849448  80773   44598      201
# 60   6.583120  78308   44368      401
# 23   0.518248  52669   40091      401
# 62  16.298459  78310   44368      401
# 61  16.973425  78309   44368      401
# 64  16.582812  78312   44368      401
# 65  16.405409  78313   44368      401
#
#                                              geometry
# 70  LINESTRING (263788.726 1940519.020, 264147.233...
# 68  LINESTRING (260134.762 1946798.667, 259968.703...
# 67  LINESTRING (255671.531 1951058.875, 255937.259...
# 69  LINESTRING (268919.978 1946682.515, 269334.421...
# 60  LINESTRING (257092.517 1951138.962, 257222.981...
# 23  LINESTRING (272432.371 1946065.153, 272328.854...
# 62  LINESTRING (268224.169 1948843.659, 268233.608...
# 61  LINESTRING (261122.248 1948792.180, 261186.287...
# 64  LINESTRING (278480.666 1953632.296, 278464.372...
# 65  LINESTRING (270489.096 1948924.405, 270340.073...

# %%
# Pendiente de la cuenca de Alvard.

# Desnivel entre curvas [km]
D = 0.2

for i in range( len( Cuencas ) ):
    Cuencas[i]["ALVARD"] = ( D * Curvas[i]["LENGTH"].sum()
        / Cuencas[i]["AREA_KM2"] )
    
    # Pendiente en m/km.
    print( "Alvard subcuenca "
        + f"{Cuencas[i].loc[0, 'SUBCUENCA']}: "
        + f"{Cuencas[i].loc[0, 'ALVARD'] * 1000:.3f}" )
# Out:
# Alvard subcuenca R. Gavia: 69.819
# Alvard subcuenca R. Petatlán: 243.802

# %%
# Cargamos la información del Río San Fernando.

for i in range( len(Rios) ):
    Rios[i] = gpd.read_file(path + nombres_r[i])
    # Mexico ITRF92 UTM 14N (EPSG:32614).
    Rios[i] = Rios[i].to_crs(32614)

# Nube de puntos con información de cotas.
print( Rios[1].head() )
# Out:
#    FNODE_  TNODE_  LPOLY_  RPOLY_   LENGTH  COV_  COV_ID     NOMBRES  \
# 0    2605    2608       0       0  0.93024  1788    1967  R. Conchos
# 1    2605    2608       0       0  0.93024  1788    1967  R. Conchos
# 2    2605    2608       0       0  0.93024  1788    1967  R. Conchos
# 3    2605    2608       0       0  0.93024  1788    1967  R. Conchos
# 4    2605    2608       0       0  0.93024  1788    1967  R. Conchos
#
#    distance       angle     xcoord     ycoord  zcoord    Distancia  \
# 0      0.93  246.784079 -99.328513  24.944138   233.0     0.000000
# 1      0.92  267.382556 -99.319082  24.947030   225.0  1004.528814
# 2      0.91  267.382556 -99.309093  24.947487   222.0  1009.753687
# 3      0.90  267.382556 -99.299103  24.947943   219.0  1009.749188
# 4      0.89  267.382556 -99.289114  24.948400   225.0  1009.744714
#
#              x                        geometry
# 0     0.000000  POINT (466834.720 2758802.322)
# 1  1004.528814  POINT (467787.592 2759120.305)
# 2  2014.282501  POINT (468796.193 2759168.540)
# 3  3024.031689  POINT (469804.786 2759216.849)
# 4  4033.776403  POINT (470813.370 2759265.232)

# %%
# Vector del río.
Rios[0].explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1f69210d3decb18a6aef144a1d0a1d7b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1f69210d3decb18a6aef144a1d0a1d7b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_1f69210d3decb18a6aef144a1d0a1d7b = L.map(
#                 &quot;map_1f69210d3decb18a6aef144a1d0a1d7b&quot;,
#                 {
#                     center: [24.92031882670478, -98.7873776792039],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_1f69210d3decb18a6aef144a1d0a1d7b);
#
#
#
#
#
#             var tile_layer_bd9bfe571dba3263979ac6ab40760723 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1f69210d3decb18a6aef144a1d0a1d7b);
#
#
#             map_1f69210d3decb18a6aef144a1d0a1d7b.fitBounds(
#                 [[24.724722926156595, -99.8795391437306], [25.115914727252964, -97.69521621467722]],
#                 {}
#             );
#
#
#         function geo_json_11b886711d2c0c99429162a7a1a1ba19_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_11b886711d2c0c99429162a7a1a1ba19_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_11b886711d2c0c99429162a7a1a1ba19_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_11b886711d2c0c99429162a7a1a1ba19_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_11b886711d2c0c99429162a7a1a1ba19_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_11b886711d2c0c99429162a7a1a1ba19.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_11b886711d2c0c99429162a7a1a1ba19_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_11b886711d2c0c99429162a7a1a1ba19 = L.geoJson(null, {
#                 onEachFeature: geo_json_11b886711d2c0c99429162a7a1a1ba19_onEachFeature,
#
#                 style: geo_json_11b886711d2c0c99429162a7a1a1ba19_styler,
#                 pointToLayer: geo_json_11b886711d2c0c99429162a7a1a1ba19_pointToLayer
#         });
#
#         function geo_json_11b886711d2c0c99429162a7a1a1ba19_add (data) {
#             geo_json_11b886711d2c0c99429162a7a1a1ba19
#                 .addData(data)
#                 .addTo(map_1f69210d3decb18a6aef144a1d0a1d7b);
#         }
#             geo_json_11b886711d2c0c99429162a7a1a1ba19_add({&quot;bbox&quot;: [-99.8795391437306, 24.724722926156595, -97.69521621467722, 25.115914727252964], &quot;features&quot;: [{&quot;bbox&quot;: [-99.8795391437306, 24.79300197344394, -99.32988282825337, 24.94355035552056], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-99.32988282825337, 24.94355035552056], [-99.37553839165011, 24.923967337331714], [-99.41073649505928, 24.897891298446506], [-99.44855693910493, 24.889411533455117], [-99.49121837500802, 24.891178869829723], [-99.52924490977087, 24.873443343045725], [-99.57817926989082, 24.86698736458296], [-99.6237799638668, 24.87340090625869], [-99.661569572139, 24.86487003123269], [-99.70410157427169, 24.872123269665213], [-99.74219754065118, 24.849717641240307], [-99.76822177324925, 24.8206109066334], [-99.79881480

# %%
# Desplazamos las coordenadas un lugar.
gs = Rios[1]["geometry"].shift(1)
# Calculamos la distancia entre dos puntos adyacentes.
Rios[1]["Distancia"] = Rios[1]["geometry"].distance(gs)
# La posición del primer punto es 0, para los demás es una suma acumulada.
Rios[1].loc[0, "Distancia"] = 0
Rios[1]["x"] = Rios[1]["Distancia"].cumsum()

# Guardamos la distancia y la cota en otras variables.
x = Rios[1]["x"]
z = Rios[1]["zcoord"]

# Escogemos los valores iniciales y finales.
x_i = x.to_numpy()[0]
x_f = x.to_numpy()[-1]
z_f = z.to_numpy()[-1]
z_i = z.to_numpy()[0]

Rios[1]
# Out:
#      FNODE_  TNODE_  LPOLY_  RPOLY_   LENGTH  COV_  COV_ID          NOMBRES  \
# 0      2605    2608       0       0  0.93024  1788    1967       R. Conchos
# 1      2605    2608       0       0  0.93024  1788    1967       R. Conchos
# 2      2605    2608       0       0  0.93024  1788    1967       R. Conchos
# 3      2605    2608       0       0  0.93024  1788    1967       R. Conchos
# 4      2605    2608       0       0  0.93024  1788    1967       R. Conchos
# ..      ...     ...     ...     ...      ...   ...     ...              ...
# 205    2600    2601       0       0  1.15536  1794    1962  R. San Fernando
# 206    2600    2601       0       0  1.15536  1794    1962  R. San Fernando
# 207    2600    2601       0       0  1.15536  1794    1962  R. San Fernando
# 208    2600    2601       0       0  1.15536  1794    1962  R. San Fernando
# 209    2600    2601       0       0  1.15536  1794    1962  R. San Fernando
#
#      distance       angle     xcoord     ycoord  zcoord    Distancia  \
# 0        0.93  246.784079 -99.328513  24.944138   233.0     0.000000
# 1        0.92  267.382556 -99.319082  24.947030   225.0  1004.528814
# 2        0.91  267.382556 -99.309093  24.947487   222.0  1009.753687
# 3        0.90  267.382556 -99.299103  24.947943   219.0  1009.749188
# 4        0.89  267.382556 -99.289114  24.948400   225.0  1009.744714
# ..        ...         ...        ...        ...     ...          ...
# 205      0.04  252.988083 -97.727834  24.940236    -8.0  1018.530522
# 206      0.03  254.948968 -97.718223  24.942993     8.0  1017.389383
# 207      0.02  254.948968 -97.708566  24.945590    10.0  1016.648970
# 208      0.01  209.974830 -97.700212  24.949882     9.0   968.269174
# 209      0.00  209.974830 -97.695216  24.958545    10.0  1083.922582
#
#                  x                        geometry
# 0         0.000000  POINT (466834.720 2758802.322)
# 1      1004.528814  POINT (467787.592 2759120.305)
# 2      2014.282501  POINT (468796.193 2759168.540)
# 3      3024.031689  POINT (469804.786 2759216.849)
# 4      4033.776403  POINT (470813.370 2759265.232)
# ..             ...                             ...
# 205  211847.408318  POINT (628442.764 2758931.559)
# 206  212864.797701  POINT (629410.356 2759245.959)
# 207  213881.446670  POINT (630382.710 2759542.779)
# 208  214849.715845  POINT (631221.644 2760026.240)
# 209  215933.638427  POINT (631716.879 2760990.414)
#
# [210 rows x 16 columns]

# %%
# Recta de compensación.
def rect_comps(z_r):
    z = (z_f - z_r ) / (x_f - x_i) * (x - x_f) + z_f
    return z

# Integral de áreas compensadas.
def area_comps(z_r):
    a = rect_comps(z_r)
    I = integrate.simpson(z - a)
    return I

# %%
# Incializamos gráfica.
fig, ax = plt.subplots()
fig.set_facecolor("w")
fig.set_size_inches(6, 6)
fig.set_dpi(150) 

# Graficamos el perfil del río.
#ax.plot(x, z)

# Encontramos la cota z_r que compensa las áreas.
# Primer intento: z_i
z_r = optimize.fsolve(area_comps, x0 = z_i)

# Graficamos la recta compensada.
z_2 = rect_comps(z_r)
#ax.plot(x, z_2)

# Dibujamos las áreas compensadas.
ax.fill_between( x, z, z_2, where = z < z_2 )
ax.fill_between( x, z, z_2, where = z > z_2 )

# Pendiente.
S = (z_r - z_f ) / (x_f - x_i)
print(f"Pendiente [m/km]: {S * 1000}")

fig.tight_layout()
plt.show()
# Out:
# Pendiente [m/km]: [0.66735957]

# %%
# Tarea:
# 1. calcular la pendiente para el río Sonora por
# desnivel medio y por áreas compensadas y comparar.
# Utilizar UTM 12N (m) EPSG:32612 (https://epsg.io/32612)
# 2. Para las dos subcuencas calcula la densidad
# de corrientes, la densidad de drenaje, y el orden de la cuenca.
# Para el orden, utiliza la columna "ORDER".

# %%
'''
# Ajustes shapefile río San Fernando.

Rios[1]["zcoord"] = np.nansum( [ Rios[1]["SAMPLE_1"],
    Rios[1]["SAMPLE_1_2"] ], axis = 0 )
Rios[1].drop(["SAMPLE_1", "SAMPLE_1_2"], axis = 1, inplace = True)

s_fer   = Rios[1][Rios[1]["NOMBRES"] == "R. San Fernando"].sort_values(
    "distance", ascending = False)
conchos = Rios[1][Rios[1]["NOMBRES"] == "R. Conchos"].sort_values(
    "distance", ascending = False)
potosi  = Rios[1][Rios[1]["NOMBRES"] == "R. Potosi"].sort_values(
    "distance", ascending = False)

Rios[1] = pd.concat( [conchos, s_fer], axis = 0 )
Rios[1].reset_index(drop = True, inplace = True)

Rios[1].to_file(path + "Coords Río San Fernando.shp")
'''
# Out:
# '\n# Ajustes shapefile río San Fernando.\n\nRios[1]["zcoord"] = np.nansum( [ Rios[1]["SAMPLE_1"],\n    Rios[1]["SAMPLE_1_2"] ], axis = 0 )\nRios[1].drop(["SAMPLE_1", "SAMPLE_1_2"], axis = 1, inplace = True)\n\ns_fer   = Rios[1][Rios[1]["NOMBRES"] == "R. San Fernando"].sort_values(\n    "distance", ascending = False)\nconchos = Rios[1][Rios[1]["NOMBRES"] == "R. Conchos"].sort_values(\n    "distance", ascending = False)\npotosi  = Rios[1][Rios[1]["NOMBRES"] == "R. Potosi"].sort_values(\n    "distance", ascending = False)\n\nRios[1] = pd.concat( [conchos, s_fer], axis = 0 )\nRios[1].reset_index(drop = True, inplace = True)\n\nRios[1].to_file(path + "Coords Río San Fernando.shp")\n'

# %%
'''
# Ajustes Shapefile Río Sonora.

u = Rios[1]["FNODE_"].unique()
u = [391, 397, 0, 426]
t = [None] * len(u)

for i in range(len(u)):
    t[i] = Rios[1][Rios[1]["FNODE_"] == u[i]
        ].sort_values( "distance", ascending = True)

Rios[1] = pd.concat( t[::-1], axis = 0 )
Rios[1].reset_index(drop = True, inplace = True)
Rios[1].rename({"SAMPLE_1": "zcoord"}, axis = 1, inplace = True)
Rios[1].to_file(path + "Coords Río Sonora.shp")
'''
# Out:
# '\n# Ajustes Shapefile Río Sonora.\n\nu = Rios[1]["FNODE_"].unique()\nu = [391, 397, 0, 426]\nt = [None] * len(u)\n\nfor i in range(len(u)):\n    t[i] = Rios[1][Rios[1]["FNODE_"] == u[i]\n        ].sort_values( "distance", ascending = True)\n\nRios[1] = pd.concat( t[::-1], axis = 0 )\nRios[1].reset_index(drop = True, inplace = True)\nRios[1].rename({"SAMPLE_1": "zcoord"}, axis = 1, inplace = True)\nRios[1].to_file(path + "Coords Río Sonora.shp")\n'

# %%
nombres_hl = ["RH12Ai_hl.shp", "RH19Be_hl.shp"]
HL = [None] * len(nombres_hl)

# Abrimos la primera subcuenca.
i = 0

for i in range( len(nombres_hl) ):
    HL[i] = gpd.read_file(path + nombres_hl[i])

    # A coordenadas UTM 14N (m) (EPSG: 32614).
    HL[i] = HL[i].to_crs(32614)

# Datos.
HL[0].head()
# Out:
#         ID CVE_SUBC CLAVE50K  TIPO            ENTIDAD    FC      CONDICION  \
# 0  6283246   RH12Ai   e14a37   101  CORRIENTE DE AGUA  3271   INTERMITENTE
# 1  6283247   RH12Ai   e14a37   101  CORRIENTE DE AGUA  3271   INTERMITENTE
# 2  6283248   RH12Ai   e14a37   101  CORRIENTE DE AGUA  3272        PERENNE
# 3  6283249   RH12Ai   e14a37   101  CORRIENTE DE AGUA  3272        PERENNE
# 4  6283250   RH12Ai   e14a37   103      LINEA CENTRAL  3273  FLUJO VIRTUAL
#
#   EDICION       FECHA   LENGTHM  ...  FLOWDIR  ENABLED  DESC_ENABL CALI_REPR  \
# 0       O  1996-01-31   99.4970  ...        1        1        None         0
# 1       O  1996-01-31  238.5890  ...        1        1        None         0
# 2       O  1996-01-31  119.6795  ...        1        1        None         0
# 3       O  1996-01-31   44.8832  ...        1        1        None         0
# 4       N  2008-01-11   60.9720  ...        1        1        None         3
#
#    SEQUENCEID  ORDER_1  LEVEL_1      ARBSUM_1     PATHL_1  \
# 0       543.0        3        3  1.118147e+04  23742.8254
# 1      1825.0        2        3  1.022193e+03  13915.9591
# 2        34.0        6        1  1.462286e+06   2423.5314
# 3      2356.0        4        2  1.004666e+05  23793.2637
# 4      2190.0        2        3  2.016882e+03  22155.2684
#
#                                             geometry
# 0  LINESTRING (420780.371 2141316.700, 420775.255...
# 1  LINESTRING (413756.581 2149747.126, 413745.369...
# 2  LINESTRING (418896.810 2154627.937, 418902.380...
# 3  LINESTRING (409227.461 2145825.808, 409218.867...
# 4  LINESTRING (406970.250 2152179.552, 406970.249...
#
# [5 rows x 21 columns]

# %%
# Forma de la cuenca.
HL[i].explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ef3d948e9c7126d5050127e1e312003f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ef3d948e9c7126d5050127e1e312003f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_ef3d948e9c7126d5050127e1e312003f = L.map(
#                 &quot;map_ef3d948e9c7126d5050127e1e312003f&quot;,
#                 {
#                     center: [17.644710742599997, -101.14352951255],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_ef3d948e9c7126d5050127e1e312003f);
#
#
#
#
#
#             var tile_layer_b9dade234841a6cb550cfaed06038ae7 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ef3d948e9c7126d5050127e1e312003f);
#
#
#             map_ef3d948e9c7126d5050127e1e312003f.fitBounds(
#                 [[17.5018342769, -101.32608219429999], [17.787587208299993, -100.9609768308]],
#                 {}
#             );
#
#
#         function geo_json_586ed43ad318da56d8fbe7d89386b196_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_586ed43ad318da56d8fbe7d89386b196_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_586ed43ad318da56d8fbe7d89386b196_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_586ed43ad318da56d8fbe7d89386b196_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_586ed43ad318da56d8fbe7d89386b196_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_586ed43ad318da56d8fbe7d89386b196.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_586ed43ad318da56d8fbe7d89386b196_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_586ed43ad318da56d8fbe7d89386b196 = L.geoJson(null, {
#                 onEachFeature: geo_json_586ed43ad318da56d8fbe7d89386b196_onEachFeature,
#
#                 style: geo_json_586ed43ad318da56d8fbe7d89386b196_styler,
#                 pointToLayer: geo_json_586ed43ad318da56d8fbe7d89386b196_pointToLayer
#         });
#
#         function geo_json_586ed43ad318da56d8fbe7d89386b196_add (data) {
#             geo_json_586ed43ad318da56d8fbe7d89386b196
#                 .addData(data)
#                 .addTo(map_ef3d948e9c7126d5050127e1e312003f);
#         }
#             geo_json_586ed43ad318da56d8fbe7d89386b196_add({&quot;bbox&quot;: [-101.32608219429999, 17.5018342769, -100.9609768308, 17.787587208299993], &quot;features&quot;: [{&quot;bbox&quot;: [-101.0813726308, 17.757047630799995, -101.07079312309997, 17.762834738499997], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-101.0813726308, 17.762834738499997], [-101.08026523079998, 17.7624670769], [-101.07924498459998, 17.762297215399993], [-101.07811118459998, 17.762092430799992], [-101.07720479999998, 17.761984599999995], [-101.07663895379997, 17.761972538499997], [-101.07568006149998, 17.762217584599995], [-101.07406339999997, 17.7618372], [-101.07377713849999, 17.761542107700002], [-101.07343056919997, 17.760922430799997], [-101.07299884609998, 17.7602765539], [-101.07274044609997, 17.759945030799994], [-101.07219227689997, 17.

# %%
Dd  = [None] * len( Cuencas )
Dc  = [None] * len( Cuencas )
Ord = [None] * len( Cuencas )

Cuencas[0].area / 1000 ** 2

for i in range( len( Cuencas ) ):
    A = Cuencas[i].area / 1000 ** 2
    Dd[i]  = ( ( HL[i]["LENGTHM"].sum() / 1000 ) / A )[0]
    Dc[i]  = ( HL[i].shape[0] / A )[0]
    Ord[i] = HL[i]["ORDER_1"].max()

    print(f"Subcuenca: {Cuencas[i].loc[0, 'SUBCUENCA']}")
    print(f"Densidad de drenaje   : {Dd[i]:.3f}")
    print(f"Densidad de corrientes: {Dd[i]:.3f} corrientes/km2")
    print(f"Orden de la subcuenca : {Ord[i]}")
    print()
# Out:
# Subcuenca: R. Gavia
# Densidad de drenaje   : 2.544
# Densidad de corrientes: 2.544 corrientes/km2
# Orden de la subcuenca : 6
#
# Subcuenca: R. Petatlán
# Densidad de drenaje   : 1.928
# Densidad de corrientes: 1.928 corrientes/km2
# Orden de la subcuenca : 5
